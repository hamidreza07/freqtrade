# %%
import pickle

# %%
with open('user_data/models/uniqe-id/historic_predictions.pkl','rb') as f:
    model = pickle.load(f)

# %%
model['BTC/USDT:USDT']
# Out:
#     &s-up_or_down      down        up  down_mean  down_std  up_mean  up_std  \
# 0              up  0.450096  0.549904        0.0       0.0      0.0     0.0
# 1              up  0.456852  0.543148        0.0       0.0      0.0     0.0
# 2              up  0.453656  0.546344        0.0       0.0      0.0     0.0
# 3              up  0.451187  0.548813        0.0       0.0      0.0     0.0
# 4              up  0.451135  0.548865        0.0       0.0      0.0     0.0
# ..            ...       ...       ...        ...       ...      ...     ...
# 995          down  0.562029  0.437971        0.0       0.0      0.0     0.0
# 996          down  0.562022  0.437979        0.0       0.0      0.0     0.0
# 997          down  0.562003  0.437997        0.0       0.0      0.0     0.0
# 998          down  0.561957  0.438043        0.0       0.0      0.0     0.0
# 999          down  0.561920  0.438080        0.0       0.0      0.0     0.0
#
#      do_predict  DI_values  close_price                 date_pred
# 0           0.0   0.000000      25921.6 2023-08-28 09:12:00+00:00
# 1           0.0   0.000000      25929.6 2023-08-28 09:15:00+00:00
# 2           0.0   0.000000      25925.2 2023-08-28 09:18:00+00:00
# 3           0.0   0.000000      25946.7 2023-08-28 09:21:00+00:00
# 4           0.0   0.000000      25945.7 2023-08-28 09:24:00+00:00
# ..          ...        ...          ...                       ...
# 995         0.0   0.000000      27421.8 2023-08-30 10:57:00+00:00
# 996         0.0   0.000000      27405.0 2023-08-30 11:00:00+00:00
# 997         0.0   0.000000      27405.4 2023-08-30 11:03:00+00:00
# 998         0.0   0.000000      27398.5 2023-08-30 11:06:00+00:00
# 999         1.0   0.204168      27392.6 2023-08-30 11:09:00+00:00
#
# [1000 rows x 11 columns]

# %%
categorical_columns = model.select_dtypes(include=['object'])
