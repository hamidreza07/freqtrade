# %%
import pickle

# %%
with open('user_data/models/uniqe-id/historic_predictions.pkl','rb') as f:
    model = pickle.load(f)

# %%
df=model['ETH/USDT:USDT']
df
# Out:
#         &-s_close  &-s_close_mean  &-s_close_std  do_predict  DI_values  \
# 0   -2.679428e+09               0              0           0          0
# 1   -3.456488e+09               0              0           0          0
# 2   -3.455984e+09               0              0           0          0
# 3   -3.456007e+09               0              0           0          0
# 4   -3.452644e+09               0              0           0          0
# ..            ...             ...            ...         ...        ...
# 995  5.379838e-04               0              0           0          0
# 996 -1.938014e-04               0              0           0          0
# 997  1.427150e-05               0              0           0          0
# 998 -4.723292e-05               0              0           0          0
# 999  2.931952e-04               0              0           0          0
#
#      close_price                 date_pred
# 0        1635.11 2023-09-07 07:48:00+00:00
# ...

# %%
categorical_columns = model.select_dtypes(include=['object'])

# %%
4800/66
# Out:
# 72.72727272727273
