# %%
import pickle

# %%
with open('user_data/models/uniqe-id/historic_predictions.backup.pkl','rb') as f:
    model2 = pickle.load(f)

# %%
model2['BTC/USDT:USDT']
# Out:
#      &-s_close  &-s_close_mean  &-s_close_std  do_predict  DI_values  \
# 0     0.007242               0              0           0          0
# 1     0.007242               0              0           0          0
# 2     0.007242               0              0           0          0
# 3     0.007242               0              0           0          0
# 4     0.007242               0              0           0          0
# ..         ...             ...            ...         ...        ...
# 995  -0.000168               0              0           0          0
# 996  -0.000168               0              0           0          0
# 997  -0.000168               0              0           0          0
# 998  -0.000168               0              0           0          0
# 999  -0.000168               0              0           0          0
#
#      close_price                 date_pred
# 0        25798.3 2023-09-10 11:21:00+00:00
# 1        25803.6 2023-09-10 11:24:00+00:00
# ...
